# %%
import pandas as pd
df = pd.read_csv("https://data.boston.gov/dataset/e02c44d2-3c64-459c-8fe2-e1ce5f38a035/resource/fd351943-c2c6-4630-992d-3f895360febd/download/ast2018full.csv")
pd.set_option('display.max_columns', 500)
df.head()
# Out:
# C:\Users\Satvir\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (15,60,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#          PID  CM_ID       GIS_ID     ST_NUM    ST_NAME ST_NAME_SUF UNIT_NUM  \
# 0  100001000    NaN  100001000.0  104 A 104     PUTNAM          ST      NaN
# 1  100002000    NaN  100002000.0      197    LEXINGTON          ST      NaN
# 2  100003000    NaN  100003000.0      199    LEXINGTON          ST      NaN
# 3  100004000    NaN  100004000.0      201    LEXINGTON          ST      NaN
# 4  100005000    NaN  100005000.0      203    LEXINGTON          ST      NaN
#
#    ZIPCODE  PTYPE  LU OWN_OCC                  OWNER          MAIL_ADDRESSEE  \
# 0   2128.0    105  R3       Y         PASCUCCI CARLO
# 1   2128.0    105  R3       N        ATANASOV DANIEL
# 2   2128.0    105  R3       N        CHEVARRIA ANA S
# ...

# %%
df2 = df[['MAIL_ADDRESS', 'ST_NAME']][df.AV_TOTAL==df.AV_TOTAL.max()]
df2.head(1)
# Out:
#       MAIL_ADDRESS  ST_NAME
# 16153     32 FRUIT  CHARLES

# %%
MEDIAN age of buildings
round(df.YR_BUILT.median())
# Out:
# 1910

# %%
 MINIMUM age of buildings in years
MINage = df.YR_BUILT.max()
MINage = 2017-MINage
MINage
# Out:
# 1.0

# %%
MAXIMUM age of buildings
MAXage = df[df.YR_BUILT >= 2]
MAXage = MAXage.YR_BUILT.min()
MAXage = 2017-MAXage
MAXage
# Out:
# 317.0

# %%
df3 = df[['MAIL_ADDRESS', 'AV_LAND', 'ST_NAME']][df.LU == 'R1']
df4 = df3.sort_values(['AV_LAND'], ascending = False)
df5 = df4.head()
df5

# df5 is the dataset, with top five single-family residences in assessed land value, and we can check the street name under ST_NAME as we have minimised the dataset and is easily visible.
# Out:
#                      MAIL_ADDRESS  AV_LAND       ST_NAME
# 45521  116 FLANDERS RD SUITE 1100  5311500  COMMONWEALTH
# 46821       132 TURNPIKE RD  #100  5185200        EXETER
# 41088     625 LIBERTY AV STE 3200  4479500     LOUISBURG
# 41271           22  LOUISBURG  SQ  4031500     LOUISBURG
# 41277             10 LOUISBURG SQ  3916300     LOUISBURG

# %%
#as we could see in df5 above LOUISBURG is the street which has three address in top five
df6 = df5.tail(3)
df6.ST_NAME
# Out:
# 41088    LOUISBURG
# 41271    LOUISBURG
# 41277    LOUISBURG
# Name: ST_NAME, dtype: object

# %%
# Answer 4 
dff = pd.read_csv("boston.csv")
dff  = dff[dff.LU == "R1"]
dff
# Out:
# C:\Users\Satvir\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (60,63) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 PID CM_ID       GIS_ID  ST_NUM    ST_NAME ST_NAME_SUF  \
# 145     0401786000_   NaN  0401786000_      38     FENWAY          ST
# 196     0100021000_   NaN  0100021000_  243 HF  LEXINGTON          ST
# 202     0100027000_   NaN  0100027000_      33   PRESCOTT          ST
# 208     0100033000_   NaN  0100033000_     246  PRINCETON          ST
# 217     0100041000_   NaN  0100041000_     224  PRINCETON          ST
# 228     0100052000_   NaN  0100052000_     112     PUTNAM          ST
# 229     0100053000_   NaN  0100053000_     110     PUTNAM          ST
# 294     0100118000_   NaN  0100118000_     1 2     LAWSON          PL
# 313     0100137000_   NaN  0100137000_   426 R   SARATOGA          ST
# ...

# %%
# filtered the dataframe to only single family residents(R1) and now groupingto streets with atleast 20 families
dff = dff.groupby('ST_NAME').filter(lambda x: len(x) > 19)
dff.ST_NAME.value_counts()
# Out:
# CENTRE          231
# PARK            174
# LAGRANGE        163
# WASHINGTON      148
# POPLAR          143
# METROPOLITAN    143
# MILTON          141
# WELD            136
# BEECH           130
# RIVER           107
# TEMPLE          106
# BAKER           103
# CHESTNUT        101
# MT VERNON       101
# PERHAM          100
# MAPLE            96
# STRATFORD        92
# POND             91
# NEPONSET         91
# HYDE PARK        88
# COREY            84
# LEXINGTON        82
# VFW              82
# W ROXBURY        81
# WEST             80
# CHURCH           79
# HUNTINGTON       78
# VERMONT          78
# SOUTH            77
# BELLEVUE         75
#                ...
# HALSEY           20
# BONAD            20
# P                20
# BLUEVIEW         20
# CARROLL          20
# REVERE           20
# KOVEY            20
# GLENHAVEN        20
# OAKCREST         20
# HOLBROOK         20
# OAK SQUARE       20
# GRAY             20
# MATTAPAN         20
# BOURNEDALE       20
# ...

# %%
dff.groupby("ST_NAME").GROSS_TAX.mean()
# Out:
# ST_NAME
# ADAMS              5.435309e+05
# ADDINGTON          4.853290e+05
# ALABAMA            2.902294e+05
# ALBION             6.017658e+05
# ALDRICH            4.639367e+05
# ALLSTON            6.136301e+05
# ALMONT             2.832053e+05
# ALWIN              2.895166e+05
# AMERICAN LEGION    3.587889e+05
# ANAWAN             6.275035e+05
# ANNAFRAN           3.013685e+05
# APPLETON           2.279593e+06
# ARBORFIELD         2.756001e+05
# ARBORWAY           1.072296e+06
# ARDALE             4.832468e+05
# ARLINGTON          4.837355e+05
# ASHEVILLE          3.679051e+05
# ASHMONT            5.121711e+05
# ATHENS             5.444113e+05
# ATHERTON           4.836408e+05
# AURIGA             4.234154e+05
# AUSTIN             3.688978e+05
# AVALON             5.166370e+05
# AYLES              3.180526e+05
# BADGER             3.544866e+05
# BAKER              4.019570e+05
# BALDWIN            7.435750e+05
# BARTLETT           7.387723e+05
# BATEMAN            3.099749e+05
# ...

# %%
g['agt'] = dff.groupby("ST_NAME").GROSS_TAX.mean()
g
# Out:
# ST_NAME
# ADAMS                                                         543531
# ADDINGTON                                                     485329
# ALABAMA                                                       290229
# ALBION                                                        601766
# ALDRICH                                                       463937
# ALLSTON                                                       613630
# ALMONT                                                        283205
# ALWIN                                                         289517
# AMERICAN LEGION                                               358789
# ANAWAN                                                        627504
# ANNAFRAN                                                      301369
# APPLETON                                                 2.27959e+06
# ARBORFIELD                                                    275600
# ...

# %%
g.agt.max()
# Out:
# 6097928.777777778
